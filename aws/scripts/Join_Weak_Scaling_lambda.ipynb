# %%
import matplotlib.pyplot as plt

# Given data
world_size = ['2', '4', '8', '16']
lambda_6GB = [20.93334174,21.65291435, 21.53548048, 22.21029407]
lambda_10GB = [20.33293915, 20.80322921, 21.40962785, 22.50992207]


lambda_6GB_err = [1.196110935, 0.4705277535, 1.146969814, 1.595795343]
lambda_10GB_err = [1.226280807, 1.214116225, 1.286160677, 0.7227855794]


# Create a line chart
plt.plot(world_size, lambda_6GB, marker='o', color='b', label='Lambda - 6GB GB Memory')
plt.plot(world_size, lambda_10GB, marker='o', color='g', label='Lambda - 10 GB Memory')


plt.errorbar(world_size, lambda_6GB, yerr=lambda_6GB_err, fmt='x', color='b', ecolor='b', capsize=5)
plt.errorbar(world_size, lambda_10GB, yerr=lambda_10GB_err, fmt='o', color='g', ecolor='g', capsize=5)


custom_text = "9.1m rows (2/4/8/16 Nodes)"
plt.text(1, 48, custom_text, fontsize=10, color='blue', ha='center')

plt.ylim(15, 25)

plt.xticks(world_size)

# Add labels and title
plt.xlabel('Parallelism')
plt.ylabel('average time (s)')
plt.title('Weak Scaling')

# Add a legend
plt.legend(loc="lower right")

plt.savefig('join-w-scaling.svg', format='svg')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Given data
world_size = ['2', '4', '8', '16']
lambda_6GB= [5.253787637, 2.497873724, 1.336760074, 0.682972908]
lambda_10GB = [5.130914986, 2.410879999, 1.264573097, 0.6489154994]



lambda_6GB_err = [0.3076192265, 0.1544407271, 0.1135481743,0.03628173794]
lambda_10GB8_err = [0.3470069355,0.1073012336, 0.09988807096,0.04571121656]



# Create a line chart
plt.plot(world_size, lambda_6GB, marker='o', color='b', label='Lambda - 6GB GB Memoryy')
plt.plot(world_size, lambda_10GB, marker='o', color='g', label='Lambda - 10GB GB Memory')



plt.errorbar(world_size, lambda_6GB, yerr=lambda_6GB_err, fmt='x', color='b', ecolor='b', capsize=5)
plt.errorbar(world_size, lambda_10GB, yerr=lambda_10GB8_err, fmt='o', color='g', ecolor='g', capsize=5)


custom_text = "4.5M rows (2/4/8/16 Nodes)"
plt.text(1, 10, custom_text, fontsize=10, color='blue', ha='center')

plt.ylim(0, 6)

plt.xticks(world_size)

# Add labels and title
plt.xlabel('parallelism')
plt.ylabel('average time (s)')
plt.title('Strong Scaling')

# Add a legend
plt.legend()

plt.savefig('join-s-scaling.svg', format='svg')

# Display the chart
plt.show()
